# %% [markdown]
# # Example of daily report

# %% [markdown]
# This is the example of daily report. The results below are from 2015-10-31.

# %% [markdown]
# ## Items sold and sales by categories

# %%
import pandas as pd

# %%
pd.read_csv('results/hql/categories.csv')
# Out:
#     i.item_category_id                      i.item_category_name  \
# 0                   20                                Игры - PS4
# 1                   23                           Игры - XBOX 360
# 2                   19                                Игры - PS3
# 3                   24                           Игры - XBOX ONE
# 4                   12                     Игровые консоли - PS4
# 5                   40                                Кино - DVD
# 6                   37                            Кино - Blu-Ray
# 7                   72                         Подарки - Фигурки
# 8                    3                          Аксессуары - PS4
# 9                   61                      Подарки - Атрибутика
# 10                  30             Игры PC - Стандартные издания
# 11                  55       Музыка - CD локального производства
# 12                  28          Игры PC - Дополнительные издания
# ...

# %% [markdown]
# ## Top 10 most sold products

# %%
pd.read_csv('results/hql/top_10_sold.csv')
# Out:
#    s.item_id      sales  items_sold  \
# 0      20949     794.00         159
# 1      10447   15220.00          34
# 2      19656   34680.75          33
# 3      19655    9538.00          32
# 4       1583  123969.00          31
# 5      19657   22090.00          30
# 6      17717   32399.00          28
# 7       9356   10773.00          27
# 8      10449   18386.25          24
# 9      21449   10776.00          24
#
#                                          i.item_name
# 0  Фирменный пакет майка 1С Интерес белый (34*42)...
# 1                                        ГОЛОВОЛОМКА
# 2                      ТЕРМИНАТОР ГЕНЕЗИС (3D BD+BD)
# 3                                 ТЕРМИНАТОР ГЕНЕЗИС
# 4  Assassin's Creed: Синдикат. Специальное издани...
# 5                            ТЕРМИНАТОР ГЕНЕЗИС (BD)
# 6               Прием денежных средств для 1С-Онлайн
# 7  Брелок Minecraft (blind-bag) Серия 2 в ассорти...
# 8                                   ГОЛОВОЛОМКА (BD)
# ...

# %% [markdown]
# ## Top 10 products with highest sales

# %%
pd.read_csv('results/hql/top_10_sales.csv')
# Out:
#    s.item_id      sales  items_sold  \
# 0       1583  123969.00          31
# 1       1586   53991.00           9
# 2       3351   51987.00          13
# 3       7223   39990.00          10
# 4       3756   37995.00           5
# 5       3350   35988.00          12
# 6       3352   35838.00          12
# 7      19656   34680.75          33
# 8      13448   33490.00           1
# 9      17717   32399.00          28
#
#                                          i.item_name
# 0  Assassin's Creed: Синдикат. Специальное издани...
# 1  Assassin's Creed: Синдикат. Чаринг-Кросс [PS4,...
# 2                      FIFA 16 [PS4, русская версия]
# 3  Uncharted: Натан Дрейк. Коллекция [PS4, русска...
# 4  Guitar Hero Live (Гитара + игра) [PS4, английс...
# 5                      FIFA 16 [PS3, русская версия]
# 6                 FIFA 16 [Xbox 360, русская версия]
# 7                      ТЕРМИНАТОР ГЕНЕЗИС (3D BD+BD)
# 8  Комплект Sony PlayStation 4 (1Tb) Black (CUH-1...
# ...

# %% [markdown]
# ## Top 10 product with highest sold difference

# %%
pd.read_csv('results/hql/top_10_difference.csv')
# Out:
#    diff.item_id  diff.daily_sold_diff  \
# 0         20949                    41
# 1          9356                    22
# 2          2423                    18
# 3         21449                    15
# 4          2404                    14
# 5         22088                    14
# 6         17717                    12
# 7         10449                    11
# 8          6936                    10
# 9         10447                    10
#
#                                          i.item_name
# 0  Фирменный пакет майка 1С Интерес белый (34*42)...
# 1  Брелок Minecraft (blind-bag) Серия 2 в ассорти...
# 2                         Crew [PS4, русская версия]
# 3                                     ХРАНИТЕЛЬ ЛУНЫ
# 4  Company of Heroes: Opposing Fronts [PC, Цифров...
# 5                  Элемент питания DURACELL LR06-BC2
# 6               Прием денежных средств для 1С-Онлайн
# 7                                   ГОЛОВОЛОМКА (BD)
# 8                     The Cave [PC, Цифровая версия]
# ...
